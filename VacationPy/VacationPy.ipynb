# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../WeatherPy/output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID           City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0   punta arenas -53.1500  -70.9167     20.06        30          75
# 1        1  marsh harbour  26.5412  -77.0636     24.66        75          30
# 2        2    yellowknife  62.4560 -114.3525    -10.71        62          40
# 3        3         anadyr  64.7500  177.4833    -25.72        76          20
# 4        4         xapuri -10.6517  -68.5044     29.31        68          72
#
#    Wind Speed Country        Date
# 0       10.29      CL  1680546333
# 1        3.80      BS  1680546962
# 2        2.06      CA  1680546784
# 3        5.00      RU  1680546965
# 4        1.97      BR  1680546966

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Humidity",
    scale = 0.5,
    color = "City"
)
#Display map
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
#My preferences
my_weather_df = pd.DataFrame(city_data_df.loc[city_data_df["Humidity"]<=70,:])
my_weather_df = pd.DataFrame(my_weather_df.loc[city_data_df["Max Temp"]<=21,:])
my_weather_df = pd.DataFrame(my_weather_df.loc[city_data_df["Max Temp"]>=9,:])
my_weather_df = pd.DataFrame(my_weather_df.loc[city_data_df["Wind Speed"]<=6,:])
my_weather_df = pd.DataFrame(my_weather_df.loc[city_data_df["Cloudiness"]<=70,:])


# Drop any rows with null values
my_weather_df = my_weather_df.dropna(how="any")
# Display sample data
my_weather_df
# Out:
#      City_ID                  City      Lat       Lng  Max Temp  Humidity  \
# 7          7                bethel  41.3712  -73.4140     14.47        41
# 57        57                albany  42.6001  -73.9662     15.69        31
# 78        78                 ravar  31.2656   56.8055     15.12        14
# 80        80             ashtabula  41.7001  -80.7665     19.31        39
# 92        92          ponta do sol  32.6667  -17.1000     20.07        61
# 95        95             mount isa -20.7333  139.5000     20.87        32
# 106      106             jamestown  42.0970  -79.2353     16.80        41
# 114      114                 mahon  39.8885    4.2658     13.31        67
# 199      199             liverpool  53.4106   -2.9779     11.16        62
# 214      214  vila franca do campo  37.7167  -25.4333     15.23        65
# 217      217           east london -33.0153   27.9116     19.52        68
# 222      222                agadir  30.4202   -9.5982     20.25        55
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = my_weather_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()
hotel_df
# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = " "
# Display sample data
hotel_df
# Out:
#                      City Country      Lat       Lng  Humidity Hotel Name
# 7                  bethel      US  41.3712  -73.4140        41
# 57                 albany      US  42.6001  -73.9662        31
# 78                  ravar      IR  31.2656   56.8055        14
# 80              ashtabula      US  41.7001  -80.7665        39
# 92           ponta do sol      PT  32.6667  -17.1000        61
# 95              mount isa      AU -20.7333  139.5000        32
# 106             jamestown      US  42.0970  -79.2353        41
# 114                 mahon      ES  39.8885    4.2658        67
# 199             liverpool      GB  53.4106   -2.9779        62
# 214  vila franca do campo      PT  37.7167  -25.4333        65
# 217           east london      ZA -33.0153   27.9116        68
# 222                agadir      MA  30.4202   -9.5982        55
# 227              ajdabiya      LY  30.7554   20.2263        51
# 231              sidi ali      DZ  36.0998    0.4206        65
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
limit = 20

#params for api
params = {
    "limit":limit,
    "apiKey":geoapify_key    
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = hotel_df.loc[index, "Lat"]
    longitude = hotel_df.loc[index, "Lng"]

    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["categories"] = f"accommodation.hotel"
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
        
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# bethel - nearest hotel: Hampton Inn Danbury
# albany - nearest hotel: No hotel found
# ravar - nearest hotel: زائر سرا راور
# ashtabula - nearest hotel: No hotel found
# ponta do sol - nearest hotel: Estalagem Ponta do Sol
# mount isa - nearest hotel: Ibis Styles
# jamestown - nearest hotel: DoubleTree Jamestown
# mahon - nearest hotel: Eurohotel
# liverpool - nearest hotel: The Lord Nelson Hotel
# vila franca do campo - nearest hotel: Vinha d'Areia Beach Hotel
# east london - nearest hotel: No hotel found
# agadir - nearest hotel: Atlantic
# ajdabiya - nearest hotel: فندق المدينة
# sidi ali - nearest hotel: Motel Kadi
# ancud - nearest hotel: Cabañas
# tateyama - nearest hotel: No hotel found
# whyalla - nearest hotel: Whyalla Playford Apartments
# ponta delgada - nearest hotel: Hotel Talisman
# ahipara - nearest hotel: YHA Ahipara
# laguna - nearest hotel: Holiday Inn Express & Suites
# clifton - nearest hotel: La Quinta Inn & Suites Clifton - Rutherford
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot

map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Humidity",
    scale = 0.7,
    color = "City",
    hover_cols = ["Hotel Name", "Country"]
)

# Display the map
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
